# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='https://covid19tracking.narrativa.com/feed_en.json')
json_readed = json.loads(r.text)
json_readed
# Out:
# comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=13%3A10&client=default_web&region=world',
#     '_id': '6658f6eb15b745e282dee2ccf6f0b3c0',
#     'id': '2020-5-27-13_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-27T12:41:04+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C298%2C685&deaths_num=341%2C118&date=27%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&deaths_num=341%2C118&date=27%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C681%2C418%29%2C%20Brasil%20%28391%2C222%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C298%2C685&deaths_num=341%2C118&date=27%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-2f39e9c455969a32a34a2b654f77c1d0',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>5,557,329</strong> people infected worldwide',
#     'content': '<p><small>Narrativa | Wednesday, May 27, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,557,329</strong>, of which <strong>2,298,685</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,681,418</strong>, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>391,222, 370,680, and 266,599</strong> cases respectively.</p><h4>Status in the world</h4><p><table width="100%"><thead><tr><th><strong>Currently Infected</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,197,587</td><td>1. The US: 1,681,418</td><td>1. Russia: 8,338</td><td>1. The US: 98,929</td><td>1. Russia: 161</td><td>1. The US: 384,902</strong></td><td>1. Russia: 11,079</strong></td></tr><tr><td>2. The United Kingdom: 228,307</td><td>2. Brazil: 391,222</td><td>2. Bangladesh: 1,541</td><td>2. The United Kingdom: 37,130</td><td>2. France: 83</td><td>2. Germany: 162,690</strong></td><td>2. Italy: 2,677</strong></td></tr><tr><td>3. Russia: 224,504</td><td>3. Russia: 370,680</td><td>3. Pakistan: 1,446</td><td>3. Italy: 32,955</td><td>3. The United Kingdom: 82</td><td>3. Brazil: 158,593</strong></td><td>3. Mexico: 2,256</strong></td></tr></tbody></table></p><p>Moreover, <strong>22,010</strong> new positive cases have been added in the last 24 hours, demonstrating a <strong>0.4</strong>% growth from the previous day. <strong> Russia</strong> is the country with the most new cases, having now confirmed <strong>8,338</strong>, followed by <b> Bangladesh</b> with <strong>1,541</strong>. <strong> Pakistan</strong> and <strong>The United Kingdom</strong> are not far behind, with <strong>1,372</strong> and <strong>1,372</strong> new patients respectively.</p><p> </p><p>So far, <strong> 341,118 people</strong> have died from the coronavirus worldwide. <strong>The US</strong> has the most victims so far with <strong>98,929</strong> deceased, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,130, 32,955, and 27,940</strong> deaths respectively.</p><p>The first evidences about this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, the infection has spread across Asia and the world. At the moment, cases in China have grown to <strong>1</strong> new cases since Tuesday. Overall, <strong>105</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C298%2C685&deaths_num=341%2C118&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C681%2C418&top_paises2=Brasil%3A%20391%2C222&top_paises3=Rusia%3A%20370%2C680&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C298%2C685&deaths_num=341%2C118&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C681%2C418&top_paises2_num=391%2C222&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=12%3A36&client=default_web&region=world',
#     '_id': '6658f6eb15b745e282dee2ccf6def733',
#     'id': '2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-27T11:06:53+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&actives_num=2%2C915%2C914&recovered_num=2%2C297%2C943&deaths_num=341%2C008&date=27%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&deaths_num=341%2C008&date=27%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C681%2C418%29%2C%20Brasil%20%28391%2C222%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&actives_num=2%2C915%2C914&recovered_num=2%2C297%2C943&deaths_num=341%2C008&date=27%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-e9ca35acd2d130b04289e3333083ca14',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>341,008</strong> deaths confirmed around the world',
#     'content': '<p><small>Narrativa | Wednesday, May 27, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,554,865</strong> Amongst this number, <strong>2,297,943</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,681,418</strong> recorded cases, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b> with <strong>391,222, 370,680, and 266,599</strong> cases respectively.</p><h4>COVID status across most infected countries</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,197,587</td><td>1. The US: 1,681,418</td><td>1. Russia: 8,338</td><td>1. The US: 98,929</td><td>1. Russia: 161</td><td>1. The US: 384,902</strong></td><td>1. Russia: 11,079</strong></td></tr><tr><td>2. The United Kingdom: 228,307</td><td>2. Brazil: 391,222</td><td>2. Pakistan: 1,446</td><td>2. The United Kingdom: 37,130</td><td>2. France: 83</td><td>2. Germany: 162,690</strong></td><td>2. Italy: 2,677</strong></td></tr><tr><td>3. Russia: 224,504</td><td>3. Russia: 370,680</td><td>3. The United Kingdom: 1,372</td><td>3. Italy: 32,955</td><td>3. The United Kingdom: 82</td><td>3. Brazil: 158,593</strong></td><td>3. Mexico: 2,256</strong></td></tr></tbody></table></p><p>Moreover, the last 24 hours have seen <strong>19,546</strong> new cases added in the last 24 hours, an increase of <strong>0.35</strong>% from the previous day. <strong> Russia</strong> is the country with the most new cases, having now confirmed <strong>8,338</strong>, followed by <b> Pakistan</b> with <strong>1,446</strong>. <strong>The United Kingdom</strong> and <strong>The US</strong> are not far behind, with <strong>1,117</strong> and <strong>1,117</strong> new patients respectively.</p><p> </p><p>So far, <strong> 341,008 people</strong> have died from the coronavirus worldwide. <strong>The US</strong> is the country with the highest count so far with <strong>98,929</strong> deceased, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,130, 32,955, and 27,940</strong> deaths respectively.</p><p>The first news of this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the world. At the moment, cases in China have increased to <strong>1</strong> new cases since yesterday. Overall, <strong>105</strong> people are infected with coronavirus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&actives_num=2%2C915%2C914&recovered_num=2%2C297%2C943&deaths_num=341%2C008&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C681%2C418&top_paises2=Brasil%3A%20391%2C222&top_paises3=Rusia%3A%20370%2C680&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&actives_num=2%2C915%2C914&recovered_num=2%2C297%2C943&deaths_num=341%2C008&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C681%2C418&top_paises2_num=391%2C222&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=11%3A03&client=default_web&region=world',
#     '_id': '6658f6eb15b745e282dee2ccf67bb59d',
#     'id': '2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
print(json_readed)
# Out:
# ctives_num=2%2C917%2C662&recovered_num=2%2C300%2C689&deaths_num=341%2C132&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C681%2C418&top_paises2_num=391%2C222&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=13%3A10&client=default_web&region=world', '_id': '6658f6eb15b745e282dee2ccf6f0b3c0', 'id': '2020-5-27-13_01-COVID-world-en_generic_COVID_EN_GENERIC'}, {'date': '2020-05-27T12:41:04+02:00', 'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C2 ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# 41%2C132&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C681%2C418&top_paises2_num=391%2C222&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=13%3A10&client=default_web&region=world", "_id": "6658f6eb15b745e282dee2ccf6f0b3c0", "id": "2020-5-27-13_01-COVID-world-en_generic_COVID_EN_GENERIC"}, {"date": "2020-05-27T12:41:04+02:00", "metadata": {"picurl_square_spain": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default", "picurl_square_spain_extended": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true", "graphs": {"graph_picurl_china": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png", "graph_picurl_us": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png", "graph_picurl_deaths_evolution": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png", "graph_picurl_world": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png", "graph_picurl_china_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png", "graph_picurl_us_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png", "graph_picurl_spain_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png", "graph_picurl_us_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png", "graph_picurl_deaths_log_evolution": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png", "graph_picurl_italy": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png", "graph_picurl_italy_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png", "graph_picurl_us_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png", "graph_picurl_italy_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png", "graph_picurl_china_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png", "graph_picurl_italy_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png", "graph_picurl_spain_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png", "graph_picurl_china_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png"}, "picurl_square_world": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C298%2C685&deaths_num=341%2C118&date=27%20de%20mayo%20del%202020&re ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)
json_readed
# Out:
# comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=13%3A10&client=default_web&region=world',
#     '_id': '6658f6eb15b745e282dee2ccf6f0b3c0',
#     'id': '2020-5-27-13_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-27T12:41:04+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C298%2C685&deaths_num=341%2C118&date=27%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&deaths_num=341%2C118&date=27%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C681%2C418%29%2C%20Brasil%20%28391%2C222%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C298%2C685&deaths_num=341%2C118&date=27%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-2f39e9c455969a32a34a2b654f77c1d0',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>5,557,329</strong> people infected worldwide',
#     'content': '<p><small>Narrativa | Wednesday, May 27, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,557,329</strong>, of which <strong>2,298,685</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,681,418</strong>, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>391,222, 370,680, and 266,599</strong> cases respectively.</p><h4>Status in the world</h4><p><table width="100%"><thead><tr><th><strong>Currently Infected</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,197,587</td><td>1. The US: 1,681,418</td><td>1. Russia: 8,338</td><td>1. The US: 98,929</td><td>1. Russia: 161</td><td>1. The US: 384,902</strong></td><td>1. Russia: 11,079</strong></td></tr><tr><td>2. The United Kingdom: 228,307</td><td>2. Brazil: 391,222</td><td>2. Bangladesh: 1,541</td><td>2. The United Kingdom: 37,130</td><td>2. France: 83</td><td>2. Germany: 162,690</strong></td><td>2. Italy: 2,677</strong></td></tr><tr><td>3. Russia: 224,504</td><td>3. Russia: 370,680</td><td>3. Pakistan: 1,446</td><td>3. Italy: 32,955</td><td>3. The United Kingdom: 82</td><td>3. Brazil: 158,593</strong></td><td>3. Mexico: 2,256</strong></td></tr></tbody></table></p><p>Moreover, <strong>22,010</strong> new positive cases have been added in the last 24 hours, demonstrating a <strong>0.4</strong>% growth from the previous day. <strong> Russia</strong> is the country with the most new cases, having now confirmed <strong>8,338</strong>, followed by <b> Bangladesh</b> with <strong>1,541</strong>. <strong> Pakistan</strong> and <strong>The United Kingdom</strong> are not far behind, with <strong>1,372</strong> and <strong>1,372</strong> new patients respectively.</p><p> </p><p>So far, <strong> 341,118 people</strong> have died from the coronavirus worldwide. <strong>The US</strong> has the most victims so far with <strong>98,929</strong> deceased, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,130, 32,955, and 27,940</strong> deaths respectively.</p><p>The first evidences about this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, the infection has spread across Asia and the world. At the moment, cases in China have grown to <strong>1</strong> new cases since Tuesday. Overall, <strong>105</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C298%2C685&deaths_num=341%2C118&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C681%2C418&top_paises2=Brasil%3A%20391%2C222&top_paises3=Rusia%3A%20370%2C680&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C557%2C329&actives_num=2%2C917%2C526&recovered_num=2%2C298%2C685&deaths_num=341%2C118&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C681%2C418&top_paises2_num=391%2C222&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=12%3A36&client=default_web&region=world',
#     '_id': '6658f6eb15b745e282dee2ccf6def733',
#     'id': '2020-5-27-12_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-27T11:06:53+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&actives_num=2%2C915%2C914&recovered_num=2%2C297%2C943&deaths_num=341%2C008&date=27%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&deaths_num=341%2C008&date=27%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C681%2C418%29%2C%20Brasil%20%28391%2C222%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&actives_num=2%2C915%2C914&recovered_num=2%2C297%2C943&deaths_num=341%2C008&date=27%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-e9ca35acd2d130b04289e3333083ca14',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>341,008</strong> deaths confirmed around the world',
#     'content': '<p><small>Narrativa | Wednesday, May 27, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,554,865</strong> Amongst this number, <strong>2,297,943</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,681,418</strong> recorded cases, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b> with <strong>391,222, 370,680, and 266,599</strong> cases respectively.</p><h4>COVID status across most infected countries</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,197,587</td><td>1. The US: 1,681,418</td><td>1. Russia: 8,338</td><td>1. The US: 98,929</td><td>1. Russia: 161</td><td>1. The US: 384,902</strong></td><td>1. Russia: 11,079</strong></td></tr><tr><td>2. The United Kingdom: 228,307</td><td>2. Brazil: 391,222</td><td>2. Pakistan: 1,446</td><td>2. The United Kingdom: 37,130</td><td>2. France: 83</td><td>2. Germany: 162,690</strong></td><td>2. Italy: 2,677</strong></td></tr><tr><td>3. Russia: 224,504</td><td>3. Russia: 370,680</td><td>3. The United Kingdom: 1,372</td><td>3. Italy: 32,955</td><td>3. The United Kingdom: 82</td><td>3. Brazil: 158,593</strong></td><td>3. Mexico: 2,256</strong></td></tr></tbody></table></p><p>Moreover, the last 24 hours have seen <strong>19,546</strong> new cases added in the last 24 hours, an increase of <strong>0.35</strong>% from the previous day. <strong> Russia</strong> is the country with the most new cases, having now confirmed <strong>8,338</strong>, followed by <b> Pakistan</b> with <strong>1,446</strong>. <strong>The United Kingdom</strong> and <strong>The US</strong> are not far behind, with <strong>1,117</strong> and <strong>1,117</strong> new patients respectively.</p><p> </p><p>So far, <strong> 341,008 people</strong> have died from the coronavirus worldwide. <strong>The US</strong> is the country with the highest count so far with <strong>98,929</strong> deceased, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,130, 32,955, and 27,940</strong> deaths respectively.</p><p>The first news of this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since that date, the number of infections have multiplied across the continent and the world. At the moment, cases in China have increased to <strong>1</strong> new cases since yesterday. Overall, <strong>105</strong> people are infected with coronavirus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&actives_num=2%2C915%2C914&recovered_num=2%2C297%2C943&deaths_num=341%2C008&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C681%2C418&top_paises2=Brasil%3A%20391%2C222&top_paises3=Rusia%3A%20370%2C680&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C554%2C865&actives_num=2%2C915%2C914&recovered_num=2%2C297%2C943&deaths_num=341%2C008&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=27%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C681%2C418&top_paises2_num=391%2C222&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/27&gen_time=11%3A03&client=default_web&region=world',
#     '_id': '6658f6eb15b745e282dee2ccf67bb59d',
#     'id': '2020-5-27-11_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
df_json = pd.read_json("data_indented.json")
df_json
# Out:
#                                                    data
# post  [{'date': '2020-07-12T13:02:22+02:00', 'metada...

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %%
# your code...

# %%
type(df_json["data"])
# Out:
# pandas.core.series.Series

# %%
with open('data_indented.json', 'r') as outfile:
    json_readed = json.load(outfile)
    for dict_ in json_readed["data"]:
        print(dict_)
# Out:
# post

# %%
with open("data_indented.json", "r+") as outfile:
    json_readed = json.load(outfile)
    data_json_list = json_readed["data"]  # Real json

# %%
with open('final_data.json', 'w+') as outfile:
    json.dump(data_json_list, outfile, indent=4)

# %%
df_data_json = pd.read_json("final_data.json")
df_data_json
# Out:
#                                                   post
# 0    {'date': '2020-07-10T02:22:27+02:00', 'metadat...
# 1    {'date': '2020-07-10T01:26:01+02:00', 'metadat...
# 2    {'date': '2020-07-10T00:10:25+02:00', 'metadat...
# 3    {'date': '2020-07-09T23:04:48+02:00', 'metadat...
# 4    {'date': '2020-07-09T22:10:29+02:00', 'metadat...
# ..                                                 ...
# 995  {'date': '2020-05-26T16:01:19+02:00', 'metadat...
# 996  {'date': '2020-05-26T15:04:17+02:00', 'metadat...
# 997  {'date': '2020-05-26T14:24:14+02:00', 'metadat...
# 998  {'date': '2020-05-26T13:16:17+02:00', 'metadat...
# 999  {'date': '2020-05-26T12:15:25+02:00', 'metadat...
#
# [1000 rows x 1 columns]

# %%
with open("data_indented.json", "r+") as outfile:
    json_readed = json.load(outfile)
    post_json_list = json_readed["data"]["post"]

# %%
with open('final_post.json', 'w+') as outfile:
    json.dump(post_json_list, outfile, indent=4)

# %%
df_post_json = pd.read_json("final_post.json")
df_post_json
# Out:
#                          date  \
# 0   2020-07-10 02:22:27+02:00
# 1   2020-07-10 01:26:01+02:00
# 2   2020-07-10 00:10:25+02:00
# 3   2020-07-09 23:04:48+02:00
# 4   2020-07-09 22:10:29+02:00
# ..                        ...
# 995 2020-05-26 16:01:19+02:00
# 996 2020-05-26 15:04:17+02:00
# 997 2020-05-26 14:24:14+02:00
# 998 2020-05-26 13:16:17+02:00
# 999 2020-05-26 12:15:25+02:00
#
#                                               metadata     author  \
# 0    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 1    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 2    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 3    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 4    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# ..                                                 ...        ...
# 995  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 996  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 997  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 998  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 999  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
#
#                                    _rev    language  \
# 0    1-38d53bf643194f8897dbaec506455670  en_generic
# 1    1-c998c203d1ac3816bc25821da9c15010  en_generic
# 2    1-5e58de840ad8839a6c7f581682e9c1d0  en_generic
# 3    1-a7a1a9d82527c46ab72eb31e0126dfc4  en_generic
# 4    1-be54b8b345a8b8a35cf703d2508b4253  en_generic
# ..                                  ...         ...
# 995  1-4456a6f5a563d15d61c1da949add033c  en_generic
# 996  1-f6223bd14af29eafbe4d891ed6dbe11a  en_generic
# 997  1-0fd4750d8c80866843e39583da34853a  en_generic
# 998  1-2ad34e91f0bdcd66ef8bdcc64bb011b0  en_generic
# 999  1-adf184482438876a3fdc69a27737b80b  en_generic
#
#                                                  title  \
# 0    Coronavirus outbreak latest: <strong>200,105</...
# 1    Coronavirus outbreak latest: <strong>149,356</...
# 2    Coronavirus outbreak latest: <strong>540,946</...
# 3    Coronavirus outbreak latest: <strong>12,086,58...
# 4    Coronavirus outbreak latest: <strong>3,137</st...
# ..                                                 ...
# 995  Coronavirus outbreak latest: <strong>337,421</...
# 996  Coronavirus outbreak latest: <strong>5,471,131...
# 997  Coronavirus outbreak latest: <strong>842</stro...
# 998  Coronavirus outbreak latest: <strong>5,466,362...
# 999  Coronavirus outbreak latest: <strong>21,342</s...
#
#                                                content  \
# 0    <p><small>Narrativa | Friday, July 10, 2020 </...
# 1    <p><small>Narrativa | Friday, July 10, 2020 </...
# 2    <p><small>Narrativa | Friday, July 10, 2020 </...
# 3    <p><small>Narrativa | Thursday, July 9, 2020 <...
# 4    <p><small>Narrativa | Thursday, July 9, 2020 <...
# ..                                                 ...
# 995  <p><small>Narrativa | Tuesday, May 26, 2020 </...
# 996  <p><small>Narrativa | Tuesday, May 26, 2020 </...
# 997  <p><small>Narrativa | Tuesday, May 26, 2020 </...
# 998  <p><small>Narrativa | Tuesday, May 26, 2020 </...
# 999  <p><small>Narrativa | Tuesday, May 26, 2020 </...
#
#                                           picurl_world  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                                 picurl metatitle subtitle  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...       ...      ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                      picurl_banner_web  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                   _id  \
# 0    3f0fa9dceb7042d2af0c938421bbf102
# 1    3f0fa9dceb7042d2af0c938421b44c5c
# 2    3f0fa9dceb7042d2af0c93842177b2a0
# 3    3f0fa9dceb7042d2af0c938421610656
# 4    3f0fa9dceb7042d2af0c938421455842
# ..                                ...
# 995  2ef525381aa6ee10546ba934454bdb14
# 996  2ef525381aa6ee10546ba93445256e4c
# 997  2ef525381aa6ee10546ba93445136c9f
# 998  521e906730f230e10f3c0f7acdede172
# 999  521e906730f230e10f3c0f7acdcb75ee
#
#                                                     id
# 0    2020-7-10-02_01-COVID-world-en_generic_COVID_E...
# 1    2020-7-10-01_01-COVID-world-en_generic_COVID_E...
# 2    2020-7-10-00_01-COVID-world-en_generic_COVID_E...
# 3    2020-7-9-23_01-COVID-world-en_generic_COVID_EN...
# 4    2020-7-9-22_01-COVID-world-en_generic_COVID_EN...
# ..                                                 ...
# 995  2020-5-26-16_01-COVID-world-en_generic_COVID_E...
# 996  2020-5-26-15_01-COVID-world-en_generic_COVID_E...
# 997  2020-5-26-14_01-COVID-world-en_generic_COVID_E...
# 998  2020-5-26-13_01-COVID-world-en_generic_COVID_E...
# 999  2020-5-26-12_01-COVID-world-en_generic_COVID_E...
#
# [1000 rows x 14 columns]

# %%
with open("data_indented.json", "r+") as outfile:
    json_readed = json.load(outfile)
    metadata_json_list = json_readed['data']['post'][1]
print(metadata_json_list)
# Out:
# {'date': '2020-07-10T01:26:01+02:00', 'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C056&actives_num=216%2C076&recovered_num=8%2C579&deaths_num=28%2C401&date=10%20de%20julio%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C056&confirmed_today_num=543&deaths_today_num=5&deaths_num=28%2C401&date=10%20de%20julio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-10-01_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C109%2C704&actives_num=5%2C018%2C989&recovered_num=6%2C549%2C708&deaths_num=541%2C007&date=10%20de%20julio%20del%202020&region=world&aspect_ratio=square&client=default', 'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C109%2C704&deaths_num=541%2C007&date=10%20de%20julio%20del%202020&top_countries=EE.UU.%20%283%2C108%2C141%29%2C%20Brasil%20%281%2C713%2C160%29%2C%20India%20%28768%2C951%29&top_spain=Madrid%20%2872%2C469%29%2C%20Catalu%C3%B1a%20%2863%2C307%29%2C%20Castilla%20y%20Le%C3%B3n%20%2819%2C782%29&region=spain&aspect_ratio=16_9&client=default', 'composition_type': 'world', 'country_selected': None, 'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confir ...

# %%
with open('final_metadata.json', 'w+') as outfile:
    json.dump(metadata_json_list, outfile, indent=4)

# %%
df_metadata_json = pd.read_json("final_metadata.json")
df_metadata_json
# Out:
#                                                   date  \
# composition_type             2020-07-10 01:26:01+02:00
# country_selected             2020-07-10 01:26:01+02:00
# graphs                       2020-07-10 01:26:01+02:00
# picurl_16_9_spain            2020-07-10 01:26:01+02:00
# picurl_square_spain          2020-07-10 01:26:01+02:00
# picurl_square_spain_extended 2020-07-10 01:26:01+02:00
# picurl_square_world          2020-07-10 01:26:01+02:00
# picurl_square_world_extended 2020-07-10 01:26:01+02:00
# state_selected               2020-07-10 01:26:01+02:00
#
#                                                                        metadata  \
# composition_type                                                          world
# country_selected                                                           None
# graphs                        {'graph_picurl_china': 'https://resources.gabr...
# picurl_16_9_spain             https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_spain           https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_spain_extended  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_world           https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_world_extended  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# state_selected                                                             None
#
#                                  author                                _rev  \
# composition_type              Narrativa  1-c998c203d1ac3816bc25821da9c15010
# country_selected              Narrativa  1-c998c203d1ac3816bc25821da9c15010
# graphs                        Narrativa  1-c998c203d1ac3816bc25821da9c15010
# picurl_16_9_spain             Narrativa  1-c998c203d1ac3816bc25821da9c15010
# picurl_square_spain           Narrativa  1-c998c203d1ac3816bc25821da9c15010
# picurl_square_spain_extended  Narrativa  1-c998c203d1ac3816bc25821da9c15010
# picurl_square_world           Narrativa  1-c998c203d1ac3816bc25821da9c15010
# picurl_square_world_extended  Narrativa  1-c998c203d1ac3816bc25821da9c15010
# state_selected                Narrativa  1-c998c203d1ac3816bc25821da9c15010
#
#                                 language  \
# composition_type              en_generic
# country_selected              en_generic
# graphs                        en_generic
# picurl_16_9_spain             en_generic
# picurl_square_spain           en_generic
# picurl_square_spain_extended  en_generic
# picurl_square_world           en_generic
# picurl_square_world_extended  en_generic
# state_selected                en_generic
#
#                                                                           title  \
# composition_type              Coronavirus outbreak latest: <strong>149,356</...
# country_selected              Coronavirus outbreak latest: <strong>149,356</...
# graphs                        Coronavirus outbreak latest: <strong>149,356</...
# picurl_16_9_spain             Coronavirus outbreak latest: <strong>149,356</...
# picurl_square_spain           Coronavirus outbreak latest: <strong>149,356</...
# picurl_square_spain_extended  Coronavirus outbreak latest: <strong>149,356</...
# picurl_square_world           Coronavirus outbreak latest: <strong>149,356</...
# picurl_square_world_extended  Coronavirus outbreak latest: <strong>149,356</...
# state_selected                Coronavirus outbreak latest: <strong>149,356</...
#
#                                                                         content  \
# composition_type              <p><small>Narrativa | Friday, July 10, 2020 </...
# country_selected              <p><small>Narrativa | Friday, July 10, 2020 </...
# graphs                        <p><small>Narrativa | Friday, July 10, 2020 </...
# picurl_16_9_spain             <p><small>Narrativa | Friday, July 10, 2020 </...
# picurl_square_spain           <p><small>Narrativa | Friday, July 10, 2020 </...
# picurl_square_spain_extended  <p><small>Narrativa | Friday, July 10, 2020 </...
# picurl_square_world           <p><small>Narrativa | Friday, July 10, 2020 </...
# picurl_square_world_extended  <p><small>Narrativa | Friday, July 10, 2020 </...
# state_selected                <p><small>Narrativa | Friday, July 10, 2020 </...
#
#                                                                    picurl_world  \
# composition_type              https://4i2g925ohj.execute-api.eu-west-3.amazo...
# country_selected              https://4i2g925ohj.execute-api.eu-west-3.amazo...
# graphs                        https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_16_9_spain             https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_spain           https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_spain_extended  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_world           https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_world_extended  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# state_selected                https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                                                          picurl  \
# composition_type              https://4i2g925ohj.execute-api.eu-west-3.amazo...
# country_selected              https://4i2g925ohj.execute-api.eu-west-3.amazo...
# graphs                        https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_16_9_spain             https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_spain           https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_spain_extended  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_world           https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_world_extended  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# state_selected                https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                              metatitle subtitle  \
# composition_type
# country_selected
# graphs
# picurl_16_9_spain
# picurl_square_spain
# picurl_square_spain_extended
# picurl_square_world
# picurl_square_world_extended
# state_selected
#
#                                                               picurl_banner_web  \
# composition_type              https://4i2g925ohj.execute-api.eu-west-3.amazo...
# country_selected              https://4i2g925ohj.execute-api.eu-west-3.amazo...
# graphs                        https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_16_9_spain             https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_spain           https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_spain_extended  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_world           https://4i2g925ohj.execute-api.eu-west-3.amazo...
# picurl_square_world_extended  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# state_selected                https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                                            _id  \
# composition_type              3f0fa9dceb7042d2af0c938421b44c5c
# country_selected              3f0fa9dceb7042d2af0c938421b44c5c
# graphs                        3f0fa9dceb7042d2af0c938421b44c5c
# picurl_16_9_spain             3f0fa9dceb7042d2af0c938421b44c5c
# picurl_square_spain           3f0fa9dceb7042d2af0c938421b44c5c
# picurl_square_spain_extended  3f0fa9dceb7042d2af0c938421b44c5c
# picurl_square_world           3f0fa9dceb7042d2af0c938421b44c5c
# picurl_square_world_extended  3f0fa9dceb7042d2af0c938421b44c5c
# state_selected                3f0fa9dceb7042d2af0c938421b44c5c
#
#                                                                              id
# composition_type              2020-7-10-01_01-COVID-world-en_generic_COVID_E...
# country_selected              2020-7-10-01_01-COVID-world-en_generic_COVID_E...
# graphs                        2020-7-10-01_01-COVID-world-en_generic_COVID_E...
# picurl_16_9_spain             2020-7-10-01_01-COVID-world-en_generic_COVID_E...
# picurl_square_spain           2020-7-10-01_01-COVID-world-en_generic_COVID_E...
# picurl_square_spain_extended  2020-7-10-01_01-COVID-world-en_generic_COVID_E...
# picurl_square_world           2020-7-10-01_01-COVID-world-en_generic_COVID_E...
# picurl_square_world_extended  2020-7-10-01_01-COVID-world-en_generic_COVID_E...
# state_selected                2020-7-10-01_01-COVID-world-en_generic_COVID_E...

# %%
with open("data_indented.json", "r+") as outfile:
    json_readed = json.load(outfile)
    metadata_graphs_json_list = json_readed['data']['post'][1]['graphs']
print(metadata2_graphs_json_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-c622d6ccee8a> in <module>
#       1 with open("data_indented.json", "r+") as outfile:
#       2     json_readed = json.load(outfile)
# ----> 3     metadata_graphs_json_list = json_readed['data']['post'][1]['graphs']
#       4 print(metadata2_graphs_json_list)
#
# KeyError: 'graphs'
