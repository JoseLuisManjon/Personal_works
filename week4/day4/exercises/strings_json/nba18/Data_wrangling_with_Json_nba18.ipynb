# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='http://data.nba.net/prod/v2/2018/teams.json')
json_readed = json.loads(r.text)
json_readed
# Out:
# onfName': 'West',
#     'divName': 'Pacific'},
#    {'isNBAFranchise': False,
#     'isAllStar': False,
#     'city': 'Guangzhou',
#     'altCityName': 'Guangzhou',
#     'fullName': 'Guangzhou Long-Lions',
#     'tricode': 'GUA',
#     'teamId': '15018',
#     'nickname': 'Long-Lions',
#     'urlName': 'long-lions',
#     'confName': 'Intl',
#     'divName': ''},
#    {'isNBAFranchise': False,
#     'isAllStar': False,
#     'city': 'Haifa',
#     'altCityName': 'Haifa',
#     'fullName': 'Maccabi Haifa',
#     'tricode': 'MAC',
#     'teamId': '93',
#     'nickname': 'Maccabi Haifa',
#     'urlName': 'maccabi_haifa',
#     'confName': 'Intl',
#     'divName': ''},
#    {'isNBAFranchise': True,
#     'isAllStar': False,
#     'city': 'Houston',
#     'altCityName': 'Houston',
#     'fullName': 'Houston Rockets',
#     'tricode': 'HOU',
#     'teamId': '1610612745',
#     'nickname': 'Rockets',
#     'urlName': 'rockets',
#     'confName': 'West',
#     'divName': 'Southwest'},
# ...

# %%
print(json_readed)
# Out:
# se, 'city': 'Adelaide', 'altCityName': 'Adelaide', 'fullName': 'Adelaide 36ers', 'tricode': 'ADL', 'teamId': '15019', 'nickname': '36ers', 'urlName': '36ers', 'confName': 'Intl', 'divName': ''}, {'isNBAFranchise': True, 'isAllStar': False, 'city': 'Atlanta', 'altCityName': 'Atlanta', 'fullName': 'Atlanta Hawks', 'tricode': 'ATL', 'teamId': '1610612737', 'nickname': 'Hawks', 'urlName': 'hawks', 'confName': 'East', 'divName': 'Southeast'}, {'isNBAFranchise': False, 'isAllStar': False, 'city': 'Beijing', 'altCityName': 'Beijing', 'fullName': 'Beijing Ducks', 'tricode': 'BJD', 'teamId': '15021', 'nickname': 'Ducks', 'urlName': 'ducks', 'confName': 'Intl', 'divName': ''}, {'isNBAFranchise': True, 'isAllStar': False, 'city': 'Boston', 'altCityName': 'Boston', 'fullName': 'Boston Celtics', 'tricode': 'BOS', 'teamId': '1610612738', 'nickname': 'Celtics', 'urlName': 'celtics', 'confName': 'East', 'divName': 'Atlantic'}, {'isNBAFranchise': True, 'isAllStar': False, 'city': 'Brooklyn', 'altCity
# ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# e, "city": "Adelaide", "altCityName": "Adelaide", "fullName": "Adelaide 36ers", "tricode": "ADL", "teamId": "15019", "nickname": "36ers", "urlName": "36ers", "confName": "Intl", "divName": ""}, {"isNBAFranchise": true, "isAllStar": false, "city": "Atlanta", "altCityName": "Atlanta", "fullName": "Atlanta Hawks", "tricode": "ATL", "teamId": "1610612737", "nickname": "Hawks", "urlName": "hawks", "confName": "East", "divName": "Southeast"}, {"isNBAFranchise": false, "isAllStar": false, "city": "Beijing", "altCityName": "Beijing", "fullName": "Beijing Ducks", "tricode": "BJD", "teamId": "15021", "nickname": "Ducks", "urlName": "ducks", "confName": "Intl", "divName": ""}, {"isNBAFranchise": true, "isAllStar": false, "city": "Boston", "altCityName": "Boston", "fullName": "Boston Celtics", "tricode": "BOS", "teamId": "1610612738", "nickname": "Celtics", "urlName": "celtics", "confName": "East", "divName": "Atlantic"}, {"isNBAFranchise": true, "isAllStar": false, "city": "Brooklyn", "altCityN
# ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)
#json_readed

# %%
df_json = pd.read_json("data_indented.json")
df_json
# Out:
#                                           _internal  \
# pubDateTime                 2018-08-30 20:00:04.422
# xslt         xsl/league/roster/marty_teams_list.xsl
# eventName                             league_roster
# standard                                        NaN
# africa                                          NaN
# sacramento                                      NaN
# vegas                                           NaN
# utah                                            NaN
#
#                                                         league
# pubDateTime                                                NaN
# xslt                                                       NaN
# eventName                                                  NaN
# standard     [{'isNBAFranchise': False, 'isAllStar': True, ...
# africa       [{'isNBAFranchise': False, 'isAllStar': False,...
# sacramento   [{'isNBAFranchise': True, 'isAllStar': False, ...
# ...

# %%
df_2_json = df_json.T
df_2_json
# Out:
#                        pubDateTime                                    xslt  \
# _internal  2018-08-30 20:00:04.422  xsl/league/roster/marty_teams_list.xsl
# league                         NaN                                     NaN
#
#                eventName                                           standard  \
# _internal  league_roster                                                NaN
# league               NaN  [{'isNBAFranchise': False, 'isAllStar': True, ...
#
#                                                       africa  \
# _internal                                                NaN
# league     [{'isNBAFranchise': False, 'isAllStar': False,...
#
#                                                   sacramento  \
# _internal                                                NaN
# league     [{'isNBAFranchise': True, 'isAllStar': False, ...
#
#                                                        vegas  \
# _internal                                                NaN
# ...

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %%
type(df_json["league"])
# Out:
# pandas.core.series.Series

# %%
#Ahora tengo que apuntar a los elementos standard, africa, sacramento.... Porque lo de arriba no nos aporta información y quiero evitarlo
df_json_league

# %%
with open('data_indented.json', 'r') as outfile:
    json_readed = json.load(outfile)
    for elem_ in json_readed["league"]:
        print(elem_)
# Out:
# standard
# africa
# sacramento
# vegas
# utah

# %%
#A PARTIR DE AQUI HABRIA QUE CONTINUAR COMO LO HA EJECUTADO EL PROFE

# %%
# Leo el archivo data_indented y lo cargo en una variable y cogo el contenido de la key/columna league

with open("data_indented.json", "r+") as outfile:
    json_readed = json.load(outfile)
    league_json_list = json_readed["league"]  # Real json
#league_json_list

# %%
#Guardo los datos en un fichero
with open('new_data.json', 'w+') as outfile:
    json.dump(league_json_list, outfile, indent=4)

# %%
df_league_json = pd.read_json("new_data.json")
df_league_json
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-9f1cd17b7e1b> in <module>
# ----> 1 df_league_json = pd.read_json("new_data.json")
#       2 df_league_json
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
# ...

# %%
# Ahora voy a intentar obtener un archivo sobre la lista de diccionarios standard
# # Leo del archivo data_indented solamente la parte de standard que es la primera key del diccionario league y lo cargo en una variable lamada standard_json_list.
with open("data_indented.json", "r+") as outfile:
    json_readed = json.load(outfile)
    standard_json_list = json_readed['league']['standard'] 
#standard_json_list

# %%
# Guardo esos datos de la standard_json_list en un archivo
with open('standard_data.json', 'w+') as outfile:
    json.dump(standard_json_list, outfile, indent=4)

# %%
df_standard_json = pd.read_json("standard_data.json")
df_standard_json
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c00b02be9851> in <module>
# ----> 1 df_standard_json = pd.read_json("standard_data.json")
#       2 df_standard_json
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
# ...

# %%
# Un nuevo metodo
FIELDS = ["league", "standard", "africa", "sacramento", "vegas", "utah"]
df = pd.json_normalize (internal ["league"])
df [internal]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-36fe1e0525f3> in <module>
#       1 # Un nuevo metodo
#       2 FIELDS = ["league", "standard", "africa", "sacramento", "vegas", "utah"]
# ----> 3 df = pd.json_normalize (internal ["league"])
#       4 df [internal]
#
# NameError: name 'internal' is not defined
